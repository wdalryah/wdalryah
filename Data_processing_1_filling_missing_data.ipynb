# %% [markdown]
# <a href="https://colab.research.google.com/github/wdalryah/wdalryah/blob/main/Data_processing_1_filling_missing_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# this code is part of the data processing procedure. one of the first step toward data prepration. in this case filling the missing data.

# %%
# display the data 

import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as cns

org_data = pd.read_csv('/content/Placement_Dataset.csv')

# %%
org_data
# Out:
#      sl_no gender  ssc_p    ssc_b  ...  specialisation  mba_p      status    salary
# 0        1      M  67.00   Others  ...          Mkt&HR  58.80      Placed  270000.0
# 1        2      M  79.33  Central  ...         Mkt&Fin  66.28      Placed  200000.0
# 2        3      M  65.00  Central  ...         Mkt&Fin  57.80      Placed  250000.0
# 3        4      M  56.00  Central  ...          Mkt&HR  59.43  Not Placed       NaN
# 4        5      M  85.80  Central  ...         Mkt&Fin  55.50      Placed  425000.0
# ..     ...    ...    ...      ...  ...             ...    ...         ...       ...
# 210    211      M  80.60   Others  ...         Mkt&Fin  74.49      Placed  400000.0
# 211    212      M  58.00   Others  ...         Mkt&Fin  53.62      Placed  275000.0
# 212    213      M  67.00   Others  ...         Mkt&Fin  69.72      Placed  295000.0
# 213    214      F  74.00   Others  ...          Mkt&HR  60.23      Placed  204000.0
# ...

# %%
org_data.head()
# Out:
#    sl_no gender  ssc_p    ssc_b  ...  specialisation  mba_p      status    salary
# 0      1      M  67.00   Others  ...          Mkt&HR  58.80      Placed  270000.0
# 1      2      M  79.33  Central  ...         Mkt&Fin  66.28      Placed  200000.0
# 2      3      M  65.00  Central  ...         Mkt&Fin  57.80      Placed  250000.0
# 3      4      M  56.00  Central  ...          Mkt&HR  59.43  Not Placed       NaN
# 4      5      M  85.80  Central  ...         Mkt&Fin  55.50      Placed  425000.0
#
# [5 rows x 15 columns]

# %%
org_data.shape
# Out:
# (215, 15)

# %%
org_data.isnull().sum()
# Out:
# sl_no              0
# gender             0
# ssc_p              0
# ssc_b              0
# hsc_p              0
# hsc_b              0
# hsc_s              0
# degree_p           0
# degree_t           0
# workex             0
# etest_p            0
# specialisation     0
# mba_p              0
# status             0
# salary            67
# dtype: int64

# %% [markdown]
# ### i will
#
# *   1- look at the data
# 2- in the sallary column wich is important
# there is an empty values
# 3 how do we fill the missing values?
# #  *etihter by **imbutation** or drop
# imbutation using mean, meadium, mode
#
# * put the data on plot to see how the data look like
# scew data means it lean on on side > we use mean in this case

# %%
# plot the data 
# we can see the data is leaned toward wine side, tha means if i chosed the imputing method then i can 
filling it using mena 

cns.distplot(org_data.salary)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# let us fill the sallry column with mean values 

org_data['salary'].fillna(org_data['salary'].median(), inplace=True)
#dataset['salary'].fillna(dataset['salary'].median(),inplace=True)

# %%
org_data.isnull().sum()
# Out:
# sl_no             0
# gender            0
# ssc_p             0
# ssc_b             0
# hsc_p             0
# hsc_b             0
# hsc_s             0
# degree_p          0
# degree_t          0
# workex            0
# etest_p           0
# specialisation    0
# mba_p             0
# status            0
# salary            0
# dtype: int64

# %%
org_data
# Out:
#      sl_no gender  ssc_p    ssc_b  ...  specialisation  mba_p      status    salary
# 0        1      M  67.00   Others  ...          Mkt&HR  58.80      Placed  270000.0
# 1        2      M  79.33  Central  ...         Mkt&Fin  66.28      Placed  200000.0
# 2        3      M  65.00  Central  ...         Mkt&Fin  57.80      Placed  250000.0
# 3        4      M  56.00  Central  ...          Mkt&HR  59.43  Not Placed  265000.0
# 4        5      M  85.80  Central  ...         Mkt&Fin  55.50      Placed  425000.0
# ..     ...    ...    ...      ...  ...             ...    ...         ...       ...
# 210    211      M  80.60   Others  ...         Mkt&Fin  74.49      Placed  400000.0
# 211    212      M  58.00   Others  ...         Mkt&Fin  53.62      Placed  275000.0
# 212    213      M  67.00   Others  ...         Mkt&Fin  69.72      Placed  295000.0
# 213    214      F  74.00   Others  ...          Mkt&HR  60.23      Placed  204000.0
# ...

# %%
# for big data  and few non values we can dorop those values. 

drop_data = pd.read_csv('/content/Placement_Dataset.csv')
drop_data.head()
# Out:
#    sl_no gender  ssc_p    ssc_b  ...  specialisation  mba_p      status    salary
# 0      1      M  67.00   Others  ...          Mkt&HR  58.80      Placed  270000.0
# 1      2      M  79.33  Central  ...         Mkt&Fin  66.28      Placed  200000.0
# 2      3      M  65.00  Central  ...         Mkt&Fin  57.80      Placed  250000.0
# 3      4      M  56.00  Central  ...          Mkt&HR  59.43  Not Placed       NaN
# 4      5      M  85.80  Central  ...         Mkt&Fin  55.50      Placed  425000.0
#
# [5 rows x 15 columns]

# %%
drop_data.isnull().sum()
# Out:
# sl_no              0
# gender             0
# ssc_p              0
# ssc_b              0
# hsc_p              0
# hsc_b              0
# hsc_s              0
# degree_p           0
# degree_t           0
# workex             0
# etest_p            0
# specialisation     0
# mba_p              0
# status             0
# salary            67
# dtype: int64

# %%
drop_data =drop_data.dropna(how='any')

# %%
drop_data.isnull().sum()
# Out:
# sl_no             0
# gender            0
# ssc_p             0
# ssc_b             0
# hsc_p             0
# hsc_b             0
# hsc_s             0
# degree_p          0
# degree_t          0
# workex            0
# etest_p           0
# specialisation    0
# mba_p             0
# status            0
# salary            0
# dtype: int64

# %%
# now check that we have less row number 
drop_data.shape
# Out:
# (148, 15)
